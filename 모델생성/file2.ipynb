# %%
import numpy as np
import pandas as pd

# %%
read_file  = pd.read_csv('competition_data/shampoo.csv')

# %%
read_file.head(50)
# Out:
#       브랜드  제품                                   제품명     용량     가격  \
# 0      TS  샴푸                  TS 골드플러스 TS 샴푸 500ml  500.0  12850
# 1      TS  샴푸                 TS 올뉴 플러스 TS 샴푸 500ml  500.0  13980
# 2      TS  샴푸             TS 뉴 프리미엄 TS 샴푸 펌프형 500ml  500.0  13950
# 3      TS  샴푸                     TS 올뉴 TS 샴푸 500ml  500.0  14450
# 4      TS  샴푸                     TS 블랙 에디션샴푸 500ml  500.0  55890
# 5      TS  샴푸                         TS 비디샴푸 500ml  500.0  11220
# 6      TS  샴푸                       TS 비오틴 샴푸 500ml  500.0  69000
# 7      TS  샴푸                   TS 트러스트 TS 샴푸 500ml  500.0  20580
# 8      TS  샴푸                   TS 프리미엄 TS 샴푸 500ml  500.0  25390
# 9      TS  샴푸               TS 내추럴 프리미엄 TS 샴푸 500ml  500.0  32190
# 10     TS  샴푸                 TS 내추럴 올뉴 TS 샴푸 500ml  500.0  31490
# 11     TS  샴푸                      TS 뉴TS 쿨샴푸 500ml  500.0  25860
# 12   모다모다  샴푸                  모다모다 프로체인지 블랙샴푸 300g  300.0  25430
# ...

# %%
read_file["가격"].head(50)
# Out:
# 0     12850
# 1     13980
# 2     13950
# 3     14450
# 4     55890
# 5     11220
# 6     69000
# 7     20580
# 8     25390
# 9     32190
# 10    31490
# 11    25860
# 12    25430
# 13    12410
# 14    13220
# 15    13990
# 16    12660
# 17    39090
# 18    39060
# 19    13420
# 20    26600
# 21    17160
# 22    14000
# 23    15290
# 24    20760
# 25    17100
# 26    32310
# 27    32950
# 28    13000
# 29    17460
# 30    78755
# 31    21980
# 32    20250
# 33    33080
# 34    32310
# 35     6180
# 36     4150
# 37     5490
# 38     6580
# 39     5610
# 40     5890
# 41     9470
# 42     6320
# 43    10490
# 44    13590
# 45    23850
# 46     8310
# 47    13090
# 48    22020
# 49    12800
# Name: 가격, dtype: int64

# %%
import pymysql
